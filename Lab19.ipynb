# %% [markdown]
# <a href="https://colab.research.google.com/github/rawoolanirudhu-lang/anirudhupython/blob/main/Lab19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 60
b = 13
print("Bitwise AND: 60 & 13 =", a & b, "(binary:", bin(a & b) +")")
print("Bitwise OR:  60 | 13 =", a | b, "(binary:", bin(a | b) +")")
print("Bitwise XOR: 60 ^ 13 =", a ^ b, "(binary:", bin(a ^ b) +")")
print("Bitwise NOT: ~60 =", ~a, "(binary:", bin(~a) + ")")
print("Bitwise Left Shift: 60 << 2 =", a << 2, "(binary:", bin(a << 2) +")")
print("Bitwise Right Shift: 60 >> 2 =", a >> 2, "(binary:", bin(a >> 2) +")")
# Out:
# Bitwise AND: 60 & 13 = 12 (binary: 0b1100)
# Bitwise OR:  60 | 13 = 61 (binary: 0b111101)
# Bitwise XOR: 60 ^ 13 = 49 (binary: 0b110001)
# Bitwise NOT: ~60 = -61 (binary: -0b111101)
# Bitwise Left Shift: 60 << 2 = 240 (binary: 0b11110000)
# Bitwise Right Shift: 60 >> 2 = 15 (binary: 0b1111)
