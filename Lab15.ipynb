# %% [markdown]
# <a href="https://colab.research.google.com/github/rawoolanirudhu-lang/anirudhupython/blob/main/Lab15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 15
b = 4
addition_result = a + b
print("Addition: {} + {} = {}".format(a,b, addition_result))
subtraction_result = a - b
print("Subtraction: {} - {} = {}".format(a,b, subtraction_result))
multiplication_result = a * b
print("Multiplication: {} * {} = {}".format(a,b, multiplication_result))
division_result = a / b
print("Division: {} / {} = {:.2f}".format(a,b, division_result))
floor_division_result = a // b
print("Floor Division: {} // {} = {}".format(a,b, floor_division_result))
modulus_result = a % b
print("Modulus: {} % {} = {}".format(a,b, modulus_result))
exponentiation_result = a ** b
print("Exponentiation: {} ** {} = {}".format(a,b, exponentiation_result))
# Out:
# Addition: 15 + 4 = 19
# Subtraction: 15 - 4 = 11
# Multiplication: 15 * 4 = 60
# Division: 15 / 4 = 3.75
# Floor Division: 15 // 4 = 3
# Modulus: 15 % 4 = 3
# Exponentiation: 15 ** 4 = 50625
